# %%
#q1

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("data.csv")

# %%
#datasets imported

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df["fixed acidity"]
# Out:
# 0        7.4
# 1        7.8
# 2        7.8
# 3       11.2
# 4        7.4
#         ...
# 1594     6.2
# 1595     5.9
# 1596     6.3
# 1597     5.9
# 1598     6.0
# Name: fixed acidity, Length: 1599, dtype: float64

# %%
df.chlorides
# Out:
# 0       0.076
# 1       0.098
# 2       0.092
# 3       0.075
# 4       0.076
#         ...
# 1594    0.090
# 1595    0.062
# 1596    0.076
# 1597    0.075
# 1598    0.067
# Name: chlorides, Length: 1599, dtype: float64

# %%
#q2

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# no NULL values present

# %%
#q3

# %%
#part a

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df["fixed acidity"])

# %%
plt.hist(df["fixed acidity"],density=1,facecolor='blue',alpha=0.6,bins=40)
# Out:
# (array([0.00442755, 0.0243515 , 0.03320659, 0.03763414, 0.0575581 ,
#         0.07969583, 0.12397129, 0.2457288 , 0.32099708, 0.34313481,
#         0.32542463, 0.21030843, 0.25015635, 0.1881707 , 0.1881707 ,
#         0.19481202, 0.12175751, 0.06862696, 0.11068865, 0.1151162 ,
#         0.09740601, 0.07526828, 0.0243515 , 0.04648923, 0.06641319,
#         0.03984791, 0.02656528, 0.03542037, 0.01771018, 0.02213773,
#         0.01328264, 0.00442755, 0.00664132, 0.00221377, 0.00221377,
#         0.        , 0.00442755, 0.        , 0.00885509, 0.00221377]),
#  array([ 4.6   ,  4.8825,  5.165 ,  5.4475,  5.73  ,  6.0125,  6.295 ,
#          6.5775,  6.86  ,  7.1425,  7.425 ,  7.7075,  7.99  ,  8.2725,
#          8.555 ,  8.8375,  9.12  ,  9.4025,  9.685 ,  9.9675, 10.25  ,
#         10.5325, 10.815 , 11.0975, 11.38  , 11.6625, 11.945 , 12.2275,
#         12.51  , 12.7925, 13.075 , 13.3575, 13.64  , 13.9225, 14.205 ,
#         14.4875, 14.77  , 15.0525, 15.335 , 15.6175, 15.9   ]),
# ...

# %%
plt.figure(figsize=(20,5),dpi=100)
plt.subplot(1,5,1)
plt.hist(df["fixed acidity"],density=1,facecolor='blue',alpha=0.6,bins=20,label="ding_dong")
plt.show()
plt.subplot(1,4,1)
plt.title("zeus")
plt.hist(df["chlorides"],density=1,facecolor='yellow',alpha=0.6,bins=10)
plt.title("dhol")
plt.subplot(1,4,2)
plt.hist(df["sulphates"],density=1,facecolor='pink',alpha=0.6,bins=20)
plt.subplot(1,4,3)
plt.hist(df["density"],density=1,facecolor='red',alpha=0.6,bins=10)
plt.subplot(1,4,4)
plt.hist(df["pH"],density=1,facecolor='brown',alpha=0.6,bins=30)
# Out:
# (array([0.01477301, 0.        , 0.01477301, 0.1181841 , 0.17727615,
#         0.10341109, 0.36932532, 0.57614749, 1.03411089, 1.53639332,
#         1.78753453, 2.00912972, 2.98414856, 2.62959625, 2.58527722,
#         2.46709311, 1.46252825, 1.27047909, 0.97501884, 0.57614749,
#         0.39887134, 0.14773013, 0.20682218, 0.07386506, 0.02954603,
#         0.        , 0.01477301, 0.02954603, 0.        , 0.02954603]),
#  array([2.74      , 2.78233333, 2.82466667, 2.867     , 2.90933333,
#         2.95166667, 2.994     , 3.03633333, 3.07866667, 3.121     ,
#         3.16333333, 3.20566667, 3.248     , 3.29033333, 3.33266667,
#         3.375     , 3.41733333, 3.45966667, 3.502     , 3.54433333,
#         3.58666667, 3.629     , 3.67133333, 3.71366667, 3.756     ,
#         3.79833333, 3.84066667, 3.883     , 3.92533333, 3.96766667,
#         4.01      ]),
#  <a list of 30 Patch objects>)

# %%
plt.hist(df["fixed acidity"],density=1,facecolor='blue',alpha=0.6,bins=20,label="ding_dong")
# plt.show()
# Out:
# (array([0.01438952, 0.03542037, 0.06862696, 0.18485004, 0.33206595,
#         0.26786653, 0.21916353, 0.19149136, 0.09519224, 0.11290242,
#         0.08633715, 0.03542037, 0.05313055, 0.03099282, 0.01992396,
#         0.00885509, 0.00442755, 0.00110689, 0.00221377, 0.00553443]),
#  array([ 4.6  ,  5.165,  5.73 ,  6.295,  6.86 ,  7.425,  7.99 ,  8.555,
#          9.12 ,  9.685, 10.25 , 10.815, 11.38 , 11.945, 12.51 , 13.075,
#         13.64 , 14.205, 14.77 , 15.335, 15.9  ]),
#  <a list of 20 Patch objects>)

# %%
import seaborn as sns

# %%
df.columns[1]
# Out:
# 'volatile acidity'

# %%
plt.figure(figsize=(120,5))
for i in range(len(df.columns)):
    print(df.columns[i])
    plt.subplot(1,len(df.columns),i+1)
    sns.boxplot(df[df.columns[i]])
    plt.show()
# Out:
# fixed acidity
# volatile acidity
# citric acid
# residual sugar
# chlorides
# free sulfur dioxide
# total sulfur dioxide
# density
# pH
# sulphates
# alcohol
# quality

# %%
#part b

# %%
plt.figure(figsize=(50,10))
for i in range(len(df.columns)-5):
    plt.subplot(1,len(df.columns),i+1)
    plt.scatter(df[df.columns[i]],df[df.columns[i+1]])
    plt.xlabel(df.columns[i])
    plt.ylabel(df.columns[i+1])

# %%
#q4

# %%
from sklearn.model_selection import train_test_split as ttl
from sklearn.neighbors import KNeighborsClassifier as KNN

# %%
y=df['quality'].values
x=df.drop('quality',axis=1).values

# %%
x
# Out:
# array([[ 7.4  ,  0.7  ,  0.   , ...,  3.51 ,  0.56 ,  9.4  ],
#        [ 7.8  ,  0.88 ,  0.   , ...,  3.2  ,  0.68 ,  9.8  ],
#        [ 7.8  ,  0.76 ,  0.04 , ...,  3.26 ,  0.65 ,  9.8  ],
#        ...,
#        [ 6.3  ,  0.51 ,  0.13 , ...,  3.42 ,  0.75 , 11.   ],
#        [ 5.9  ,  0.645,  0.12 , ...,  3.57 ,  0.71 , 10.2  ],
#        [ 6.   ,  0.31 ,  0.47 , ...,  3.39 ,  0.66 , 11.   ]])

# %%
x_train,x_test,y_train,y_test=ttl(x,y,test_size=0.3,stratify=y,random_state=7)

# %%
y_test
# Out:
# array([5, 6, 6, 6, 5, 5, 7, 7, 7, 6, 5, 5, 5, 6, 6, 5, 5, 5, 5, 5, 5, 6,
#        6, 6, 5, 5, 6, 6, 5, 5, 6, 5, 5, 5, 6, 6, 5, 5, 5, 5, 5, 4, 5, 5,
#        6, 5, 7, 5, 6, 7, 6, 6, 6, 6, 6, 6, 7, 6, 7, 4, 7, 5, 4, 6, 5, 5,
#        6, 5, 6, 5, 5, 6, 5, 5, 5, 6, 5, 7, 5, 7, 6, 8, 7, 5, 6, 6, 5, 5,
#        6, 5, 6, 5, 6, 6, 7, 6, 6, 5, 5, 5, 6, 5, 6, 5, 5, 6, 4, 5, 4, 4,
#        6, 6, 6, 5, 6, 6, 6, 6, 5, 7, 5, 6, 5, 6, 7, 6, 5, 5, 6, 6, 5, 5,
#        5, 8, 6, 6, 5, 7, 5, 6, 6, 5, 6, 5, 6, 5, 6, 6, 6, 6, 6, 7, 6, 5,
#        5, 5, 6, 7, 6, 5, 4, 6, 5, 5, 5, 5, 5, 6, 6, 6, 6, 5, 8, 6, 4, 6,
#        6, 5, 6, 5, 5, 5, 6, 7, 5, 4, 5, 5, 5, 5, 6, 3, 5, 6, 6, 5, 5, 5,
#        5, 5, 6, 5, 6, 5, 5, 5, 5, 6, 5, 6, 6, 6, 6, 6, 6, 5, 4, 6, 5, 5,
#        6, 6, 5, 4, 5, 5, 5, 6, 7, 7, 6, 6, 7, 7, 6, 5, 6, 5, 5, 7, 6, 6,
#        6, 6, 5, 7, 7, 5, 6, 6, 6, 6, 7, 6, 6, 6, 5, 5, 7, 5, 5, 5, 6, 6,
#        6, 6, 4, 5, 5, 5, 5, 5, 5, 6, 7, 6, 5, 6, 5, 5, 6, 7, 6, 5, 7, 5,
# ...

# %%
model=KNN(n_neighbors=16)

# %%
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=16, p=2,
#                      weights='uniform')

# %%
y_predict=model.predict(x_test)
y_predict
# Out:
# array([5, 5, 6, 6, 5, 5, 6, 6, 5, 6, 5, 6, 7, 6, 6, 5, 6, 5, 6, 5, 6, 5,
#        6, 7, 6, 6, 5, 6, 5, 5, 5, 6, 5, 5, 6, 5, 5, 5, 6, 5, 5, 5, 6, 5,
#        6, 6, 6, 5, 5, 6, 6, 5, 6, 6, 6, 5, 7, 5, 5, 6, 6, 5, 6, 6, 5, 5,
#        6, 5, 5, 6, 7, 5, 5, 5, 6, 5, 6, 7, 6, 6, 5, 6, 7, 5, 6, 6, 5, 5,
#        5, 5, 5, 6, 5, 6, 5, 5, 6, 5, 5, 5, 6, 5, 5, 6, 5, 6, 6, 6, 5, 5,
#        5, 5, 5, 5, 7, 6, 6, 5, 5, 6, 6, 6, 5, 5, 5, 5, 5, 5, 5, 7, 6, 5,
#        5, 6, 5, 6, 5, 5, 5, 5, 5, 5, 5, 6, 5, 5, 5, 6, 6, 5, 6, 7, 6, 5,
#        5, 5, 5, 6, 6, 6, 5, 6, 5, 5, 5, 5, 5, 6, 7, 5, 5, 5, 6, 6, 5, 6,
#        6, 5, 6, 7, 6, 5, 6, 5, 5, 6, 7, 6, 5, 5, 6, 7, 6, 6, 5, 5, 5, 5,
#        5, 6, 5, 5, 5, 6, 5, 5, 6, 6, 5, 5, 6, 6, 5, 6, 6, 5, 5, 6, 5, 5,
#        5, 6, 5, 5, 6, 5, 5, 6, 6, 5, 5, 6, 6, 5, 5, 5, 6, 5, 5, 7, 5, 6,
#        6, 6, 6, 5, 6, 5, 5, 6, 5, 5, 6, 5, 5, 5, 5, 6, 5, 6, 5, 6, 5, 6,
#        6, 5, 6, 6, 5, 7, 5, 5, 6, 5, 5, 6, 5, 5, 5, 5, 6, 6, 6, 6, 6, 7,
# ...

# %%
model.score(x_test,y_test)
# Out:
# 0.5208333333333334

# %%
zeus=[]
for i in range(1,60):
    model=KNN(n_neighbors=i)
    model.fit(x_train,y_train)
    zeus.append(model.score(x_test,y_test))

# %%
plt.plot(zeus)

# %%
print(type(zeus))
zeus
#scores
# Out:
# <class 'list'>
# [0.5666666666666667,
#  0.5104166666666666,
#  0.47708333333333336,
#  0.50625,
#  0.48125,
#  0.49375,
#  0.5,
#  0.51875,
#  0.5145833333333333,
#  0.51875,
#  0.5041666666666667,
#  0.51875,
#  0.50625,
#  0.51875,
#  0.5145833333333333,
#  0.5208333333333334,
#  0.5145833333333333,
#  0.51875,
#  0.5125,
#  0.5041666666666667,
#  0.50625,
#  0.51875,
#  0.50625,
#  0.5041666666666667,
#  0.5041666666666667,
#  0.5083333333333333,
#  0.5166666666666667,
#  0.51875,
#  0.5145833333333333,
#  0.5208333333333334,
#  0.5229166666666667,
#  0.525,
#  0.525,
#  0.53125,
#  0.5208333333333334,
#  0.5291666666666667,
#  0.525,
#  0.5270833333333333,
#  0.5270833333333333,
#  0.5375,
#  0.5395833333333333,
#  0.5333333333333333,
#  0.5270833333333333,
#  0.5375,
#  0.5395833333333333,
#  0.5270833333333333,
#  0.5333333333333333,
#  0.53125,
#  0.5270833333333333,
#  0.5208333333333334,
#  0.51875,
#  0.53125,
#  0.5208333333333334,
#  0.51875,
#  0.525,
#  0.525,
# ...
